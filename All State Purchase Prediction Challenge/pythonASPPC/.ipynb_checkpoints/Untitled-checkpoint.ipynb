# %%
import pandas as pd

train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

#customer1 = train[train['customer_ID'] == 10000000]
train.columns
# Out:
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time',
#        u'state', u'location', u'group_size', u'homeowner', u'car_age',
#        u'car_value', u'risk_factor', u'age_oldest', u'age_youngest',
#        u'married_couple', u'C_previous', u'duration_previous', u'A', u'B',
#        u'C', u'D', u'E', u'F', u'G', u'cost'],
#       dtype='object')

# %%
#looking for correlations between number of times a policy view and purchase
#train.groupby(['customer_ID','record_type','A','B','C','D','E','F','G']).size()

#train[['customer_ID','A','B','C','D','E','F','G']][(train.record_type == 1) | (train.shopping_pt == 1)]

sold_records_only = train[['customer_ID','record_type','A','B','C','D','E','F','G']][(train.record_type == 1)]
filtered_columns = train[['customer_ID','record_type','A','B','C','D','E','F','G']]



merged = pd.merge(sold_records_only,filtered_columns,on=['customer_ID','record_type'])

merged
# Out:
#        customer_ID  record_type  A_x  B_x  C_x  D_x  E_x  F_x  G_x  A_y  B_y  \
# 0         10000000            1    1    0    2    2    1    2    1    1    0
# 1         10000005            1    0    0    3    2    0    0    2    0    0
# 2         10000007            1    0    0    1    2    0    0    1    0    0
# 3         10000013            1    1    1    3    2    1    1    3    1    1
# 4         10000014            1    1    1    1    1    0    2    2    1    1
# 5         10000016            1    2    0    3    3    0    3    3    2    0
# 6         10000019            1    2    1    2    3    1    2    3    2    1
# 7         10000023            1    1    1    1    3    1    1    2    1    1
# 8         10000025            1    0    0    1    1    0    0    3    0    0
# 9         10000026            1    1    1    3    3    1    2    3    1    1
# 10        10000027            1    0    0    2    2    0    0    1    0    0
# ...
