# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "./input/"]).decode("utf8"))
#print(check_output(["ls", "../input/stage1_train/"]).decode("utf8"))
# Out:
# stage1_test
# stage1_test.zip
# stage1_train
# stage1_train.zip

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import os
from tqdm import tqdm
from skimage.transform import resize
# %matplotlib inline

# %%
image_heigth = 256
image_width = 256

mask_heigth = 256
mask_width = 256

def get_images_masks(root_dir):

    images = []
    for image_folder in tqdm(os.listdir(root_dir)[1:]):
        image_id = image_folder
        image_dir = root_dir + image_folder
        image_file = image_dir + '/images/' + image_id + '.png'
        image = mpimg.imread(image_file)
        image = resize(image, (image_heigth, image_width), mode='constant', preserve_range=True)
        masks = np.zeros((mask_heigth,mask_width))
        masks_dir = image_dir + '/masks/'
        
        for mask in os.listdir(masks_dir):
            mask_file = masks_dir + mask
            mask = mpimg.imread(mask_file)
            mask = resize(mask, (mask_heigth,mask_width), mode='constant', preserve_range=True)
            masks = np.add(masks,mask)
        
        images.append({'image_id': image_id, 'image': image,'masks': masks })
        
    return images

def plot_images(rows,cols,images):
    image_index = 0
    fig, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(30,30), squeeze=False)
    for r in range(rows):
        for c in range(cols):
            ax[r][c].imshow(images[image_index])
            image_index += 1

# %%
images = get_images_masks("./stage1_train/")
# Out:
# 100%|██████████| 670/670 [03:08<00:00,  3.55it/s]

# %%
images_array = [image['image'] for image in images]
plot_images(rows=1,cols=5,images=images_array)

# %%
X_train = np.array(images_array).reshape(670,image_heigth,image_width,4)
print(X_train.shape)
# Out:
# (670, 256, 256, 4)

# %%
masks_array = [image['masks'] for image in images]
plot_images(rows=1,cols=5,images=masks_array)

# %%
Y_train = np.array(masks_array).reshape(670,mask_heigth,mask_width,1)
print(Y_train.shape)
# Out:
# (670, 256, 256, 1)

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Cropping2D, Dropout, BatchNormalization
from keras.models import Model, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from keras.optimizers import SGD, Adam

# %%
def model(height,width,channels):
    X_Input = Input(shape=(height,width,channels))
    X = Conv2D(filters=8, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X_Input)
    X = Conv2D(filters=8, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    
    X = MaxPooling2D(pool_size=(2,2), strides=2)(X)
    X = Conv2D(filters=16, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)    
    X = Conv2D(filters=16, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    
    X = MaxPooling2D(pool_size=(2,2), strides=2)(X)    
    X = Conv2D(filters=32, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=32, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    
    X = MaxPooling2D(pool_size=(2,2), strides=2)(X)    
    X = Conv2D(filters=64, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=64, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    
    X = MaxPooling2D(pool_size=(2,2), strides=2)(X)    
    X = Conv2D(filters=128, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=128, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    X = Conv2DTranspose(filters=512, kernel_size=(2,2), strides=(2,2),activation='relu')(X)
    #X = concatenate([X,CX4])
    X = Conv2D(filters=64, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=64, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    X = Conv2DTranspose(filters=32, kernel_size=(2,2), strides=(2,2),activation='relu')(X)
    #X = concatenate([X,CX3])
    X = Conv2D(filters=32, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=32, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    X = Conv2DTranspose(filters=16, kernel_size=(2,2), strides=(2,2),activation='relu', kernel_initializer='he_normal')(X)
    #X = concatenate([X,CX2])
    X = Conv2D(filters=16, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=18, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.25)(X)
    #X = BatchNormalization()(X)
    
    X = Conv2DTranspose(filters=8, kernel_size=(2,2), strides=(2,2),activation='relu', kernel_initializer='he_normal')(X)
    #X = concatenate([X,CX1])
    X = Conv2D(filters=8, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    X = Conv2D(filters=8, kernel_size=(3,3),activation='relu', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    #X = Dropout(0.1)(X)
    #X = BatchNormalization()(X)
    
    X = Conv2D(filters=1, kernel_size=(3,3),activation='sigmoid', strides=(1,1), padding='same', kernel_initializer='he_normal')(X)
    
    model = Model(input=X_Input, output=X)
    model.summary()
    
    return model

# %%
model = model(image_heigth,image_width,4)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        (None, 256, 256, 4)       0
# _________________________________________________________________
# conv2d_363 (Conv2D)          (None, 256, 256, 8)       296
# _________________________________________________________________
# conv2d_364 (Conv2D)          (None, 256, 256, 8)       584
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_365 (Conv2D)          (None, 128, 128, 16)      1168
# _________________________________________________________________
# conv2d_366 (Conv2D)          (None, 128, 128, 16)      2320
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_367 (Conv2D)          (None, 64, 64, 32)        4640
# _________________________________________________________________
# conv2d_368 (Conv2D)          (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_80 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_369 (Conv2D)          (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_370 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_371 (Conv2D)          (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_372 (Conv2D)          (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_transpose_77 (Conv2DT (None, 32, 32, 512)       262656
# _________________________________________________________________
# conv2d_373 (Conv2D)          (None, 32, 32, 64)        294976
# _________________________________________________________________
# conv2d_374 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_transpose_78 (Conv2DT (None, 64, 64, 32)        8224
# _________________________________________________________________
# conv2d_375 (Conv2D)          (None, 64, 64, 32)        9248
# _________________________________________________________________
# conv2d_376 (Conv2D)          (None, 64, 64, 32)        9248
# _________________________________________________________________
# conv2d_transpose_79 (Conv2DT (None, 128, 128, 16)      2064
# _________________________________________________________________
# conv2d_377 (Conv2D)          (None, 128, 128, 16)      2320
# _________________________________________________________________
# conv2d_378 (Conv2D)          (None, 128, 128, 18)      2610
# _________________________________________________________________
# conv2d_transpose_80 (Conv2DT (None, 256, 256, 8)       584
# _________________________________________________________________
# conv2d_379 (Conv2D)          (None, 256, 256, 8)       584
# _________________________________________________________________
# conv2d_380 (Conv2D)          (None, 256, 256, 8)       584
# _________________________________________________________________
# conv2d_381 (Conv2D)          (None, 256, 256, 1)       73
# =================================================================
# Total params: 925,219
# Trainable params: 925,219
# Non-trainable params: 0
# _________________________________________________________________
# /Users/labibfawaz/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:66: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., inputs=Tensor("in...)`

# %%
for i in range(1):
    r = -4 * np.random.rand()
    lr = 0.001#10 ** r
#lr = 0.00040681225534719504
    print("learning rate: ", lr)
    optimizer = Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(optimizer=optimizer,loss='binary_crossentropy')
    earlystopper = EarlyStopping(patience=3, verbose=1)
    csv_logger = CSVLogger('dsBowlTraining_noBN_noDO_no_CC_lr_' + str(lr) + '.csv')
    model_name = 'dsBowlModel__noBN_noDO_no_CC_lr_lr_' + str(lr) + '.h5'
    checkpointer = ModelCheckpoint(model_name, verbose=1, save_best_only=True)
    results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=32, epochs=50, 
                        callbacks=[checkpointer, earlystopper, csv_logger])
# Out:
# ('learning rate: ', 0.001)
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.4200
# Epoch 00001: val_loss improved from inf to 0.38967, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 114s 189ms/step - loss: 0.4199 - val_loss: 0.3897
# Epoch 2/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.4039
# Epoch 00002: val_loss improved from 0.38967 to 0.37839, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 103s 171ms/step - loss: 0.4028 - val_loss: 0.3784
# Epoch 3/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.3950
# Epoch 00003: val_loss improved from 0.37839 to 0.36373, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 173ms/step - loss: 0.3934 - val_loss: 0.3637
# Epoch 4/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.3857
# Epoch 00004: val_loss improved from 0.36373 to 0.35526, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 104s 173ms/step - loss: 0.3839 - val_loss: 0.3553
# Epoch 5/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.3166
# Epoch 00005: val_loss improved from 0.35526 to 0.28842, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.3166 - val_loss: 0.2884
# Epoch 6/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.2785
# Epoch 00006: val_loss improved from 0.28842 to 0.23428, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 108s 180ms/step - loss: 0.2774 - val_loss: 0.2343
# Epoch 7/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.2324
# Epoch 00007: val_loss improved from 0.23428 to 0.20101, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 104s 172ms/step - loss: 0.2350 - val_loss: 0.2010
# Epoch 8/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.2095
# Epoch 00008: val_loss improved from 0.20101 to 0.18574, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.2084 - val_loss: 0.1857
# Epoch 9/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1716
# Epoch 00009: val_loss improved from 0.18574 to 0.14054, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.1701 - val_loss: 0.1405
# Epoch 10/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1517
# Epoch 00010: val_loss improved from 0.14054 to 0.13286, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.1532 - val_loss: 0.1329
# Epoch 11/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1393
# Epoch 00011: val_loss did not improve
# 603/603 [==============================] - 105s 174ms/step - loss: 0.1389 - val_loss: 0.1338
# Epoch 12/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1271
# Epoch 00012: val_loss improved from 0.13286 to 0.11876, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.1276 - val_loss: 0.1188
# Epoch 13/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1264
# Epoch 00013: val_loss improved from 0.11876 to 0.11421, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 106s 175ms/step - loss: 0.1268 - val_loss: 0.1142
# Epoch 14/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1198
# Epoch 00014: val_loss improved from 0.11421 to 0.10489, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 104s 173ms/step - loss: 0.1197 - val_loss: 0.1049
# Epoch 15/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1112
# Epoch 00015: val_loss improved from 0.10489 to 0.09855, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 175ms/step - loss: 0.1113 - val_loss: 0.0986
# Epoch 16/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1057
# Epoch 00016: val_loss did not improve
# 603/603 [==============================] - 105s 175ms/step - loss: 0.1052 - val_loss: 0.1013
# Epoch 17/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1094
# Epoch 00017: val_loss did not improve
# 603/603 [==============================] - 104s 173ms/step - loss: 0.1086 - val_loss: 0.0993
# Epoch 18/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1045
# Epoch 00018: val_loss improved from 0.09855 to 0.09432, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 105s 174ms/step - loss: 0.1043 - val_loss: 0.0943
# Epoch 19/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1036
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 104s 173ms/step - loss: 0.1035 - val_loss: 0.1013
# Epoch 20/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.1032
# Epoch 00020: val_loss improved from 0.09432 to 0.09167, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 103s 171ms/step - loss: 0.1038 - val_loss: 0.0917
# Epoch 21/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.0984
# Epoch 00021: val_loss did not improve
# 603/603 [==============================] - 104s 172ms/step - loss: 0.0999 - val_loss: 0.0964
# Epoch 22/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.0969
# Epoch 00022: val_loss improved from 0.09167 to 0.09105, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 103s 171ms/step - loss: 0.0975 - val_loss: 0.0911
# Epoch 23/50
# 576/603 [===========================>..] - ETA: 25s - loss: 0.0939
# Epoch 00023: val_loss improved from 0.09105 to 0.08979, saving model to dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5
# 603/603 [==============================] - 554s 918ms/step - loss: 0.0937 - val_loss: 0.0898
# Epoch 24/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.0919
# Epoch 00024: val_loss did not improve
# 603/603 [==============================] - 107s 177ms/step - loss: 0.0916 - val_loss: 0.1006
# Epoch 25/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.0911
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 106s 176ms/step - loss: 0.0908 - val_loss: 0.0904
# Epoch 26/50
# 576/603 [===========================>..] - ETA: 4s - loss: 0.0982
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 106s 176ms/step - loss: 0.0985 - val_loss: 0.1011
# Epoch 00026: early stopping

# %%
results = load_model('./dsBowlModel__noBN_noDO_no_CC_lr_lr_0.001.h5')

# %%
Y_train_pred = results.predict(X_train,verbose=1)
# Out:
# 670/670 [==============================] - 77s 114ms/step

# %%
Y_train_pred = (Y_train_pred.reshape(670,mask_heigth,mask_width) > 0.5).astype(int)
plot_images(rows=1,cols=5,images=Y_train_pred)

# %%
Y_train_true = (Y_train_true.reshape(670,mask_heigth,mask_width) > 0.5).astype(int)
plot_images(rows=1,cols=5,images=Y_train_true)

# %%
from scipy import ndimage
from sklearn.metrics import hamming_loss

# %%
def calculate_pixel_error(y_true, y_pred):
    n = len(y_true)
    errors = []
    pixel_length = mask_heigth*mask_width
    for i in range(n):
        error = hamming_loss(y_true[i].flatten(),y_pred[i].flatten())
        errors.append(error)

    pixel_error = np.sum(errors)/n
    
    return pixel_error

# %%
print "Traing Pixel Error:", calculate_pixel_error(Y_train_true,Y_train_pred)
# Out:
# Traing Pixel Error: 0.038730336659

# %%
def separate_masks(combined_masks):
    labeled_masks = ndimage.label(combined_masks)
    masks = []
    for i in range(1,labeled_masks[1]+1):
        mask = (labeled_masks[0] == i).astype(int)
        masks.append(mask)
    
    return masks

# %%
def identify_postive_pixels(mask):
    mask = mask.T.flatten()
    positive_pixels = []
    for i in range(len(mask)):
        if(mask[i] == 1):
            positive_pixels.append(i+1)
        
    return positive_pixels

# %%
def encode_postive_pixels(postive_pixels):
    EncodedPixels = []
    for i in range(len(postive_pixels)):
        if(postive_pixels[i] - 1 in postive_pixels):
            EncodedPixels[-1][1] += 1


        else:                 
            EncodedPixels.append([postive_pixels[i],1])
            
    encodedPixels = ''    
    for item in EncodedPixels:
        for i in item:
            encodedPixels = encodedPixels + str(i) + ' '
           

    return encodedPixels

# %%
image1 = Y_train_pred[0]
#plt.imshow(image1)

masks = separate_masks(image1)
postive_pixels = identify_postive_pixels(masks[0])
encoded_pixels = encode_postive_pixels(postive_pixels)

# %%
print encoded_pixels
# Out:
# 7682 1 7937 3 8193 4 8449 5 8705 5 8961 5 9217 6 9473 6 9729 6 9985 5 10241 5 10497 4 10753 3

# %%
def get_test_images(root_dir,model):
    images = []
    for image_folder in tqdm(os.listdir(root_dir)[1:]):
        image_id = image_folder
        image_dir = root_dir + image_folder
        image_file = image_dir + '/images/' + image_id + '.png'
        
        image = mpimg.imread(image_file) 
        images.append({'image_id': image_id, 'image': image })
    
    return images

# %%
test_images = get_test_images('./stage1_test/','a')
# Out:
# 100%|██████████| 65/65 [00:00<00:00, 155.57it/s]

# %%
test_images_array = [image['image'] for image in test_images]
plot_images(rows=1,cols=5,images=test_images_array)

# %%
def create_predicted_masks(images_array,model):
    X_test = []
    for image in images_array:      
        image = resize(image, (image_heigth, image_width, 4), mode='constant', preserve_range=True)
        X_test.append(image)
    
    X_test = np.array(X_test).reshape(65,mask_heigth,mask_width,4)
    Y_test_pred = model.predict(X_test,verbose=1)
    Y_test_pred = (Y_test_pred.reshape(65,mask_heigth,mask_width) > 0.5).astype(int)
    return Y_test_pred

# %%
test_masks = create_predicted_masks(test_images_array,results)
# Out:
# 65/65 [==============================] - 5s 76ms/step

# %%
def resize_image_masks(images_array,masks):
    i = 0
    org_masks = []
    for i in range(len(masks)):
        heigth, width = (images_array[i].shape[0], images_array[i].shape[1])
        mask = resize(masks[i], (heigth, width), mode='constant', preserve_range=True)
        org_masks.append(mask)
        
    return org_masks

# %%
resized_masks = resize_image_masks(test_images_array, test_masks)
plot_images(rows=1,cols=5,images=resized_masks)

# %%
def create_submission_dataFrame(test_images,resized_masks):
    submission = []
    for index in tqdm(range(len(test_images))):
        image_id = test_images[index]['image_id']
        masks = separate_masks(resized_masks[index])
        for j in range(len(masks)):
            postive_pixels = identify_postive_pixels(masks[j])
            encoded_pixels = encode_postive_pixels(postive_pixels)
            submission.append([image_id, encoded_pixels])
    return pd.DataFrame(np.array(submission),columns=['ImageId','EncodedPixels'])

# %%
stage1_test = create_submission_dataFrame(test_images,resized_masks)
# Out:
# 100%|██████████| 65/65 [02:11<00:00,  2.02s/it]

# %%
stage1_test.to_csv('stage1_test_labels.csv',index=False)

# %%
LB_Score='0.163'
